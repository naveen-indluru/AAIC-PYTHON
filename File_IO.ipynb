# %% [markdown]
# # FILE I/O

# %% [markdown]
# File is a named location on disk to store related information. It is used to permanently store data in a non-volatile memory (e.g. hard disk).
#
# Since, random access memory (RAM) is volatile which loses its data when computer is turned off, we use files for future use of the data.
#
# When we want to read from or write to a file we need to open it first. When we are done, it needs to be closed, so that resources that are tied with the file are freed.
#
# File operation:
#
# 1. Open a file
#
# 2. Read or write (perform operation)
#
# 3. Close the file

# %% [markdown]
# # Opening a File

# %% [markdown]
# Python has a built-in function open() to open a file. This function returns a file object, also called a handle, as it is used to read or modify the file accordingly.

# %%
f = open('example.txt') #open file in current direcotry

# %% [markdown]
# We can specify the mode while opening a file. In mode, we specify whether we want to read 'r', write 'w' or append 'a' to the file. We also specify if we want to open the file in text mode or binary mode.

# %% [markdown]
# # Python File Modes

# %% [markdown]
# 'r' Open a file for reading. (default)
#
# 'w' Open a file for writing. Creates a new file if it does not exist or truncates the file if it exists.
#
# 'x' Open a file for exclusive creation. If the file already exists, the operation fails.
#
# 'a' Open for appending at the end of the file without truncating it. Creates a new file if it does not exist.
#
# 't' Open in text mode. (default)
#
# 'b' Open in binary mode.
#
# '+' Open a file for updating (reading and writing)

# %%
f = open('example.txt') #equivalent to 'r' 
f = open('example.txt', 'r')

f = open('test.txt', 'w')

# %% [markdown]
# The default encoding is platform dependent. In windows, it is 'cp1252' but 'utf-8' in Linux.
#
# So, we must not also rely on the default encoding or else our code will behave differently in different platforms.
#
# Hence, when working with files in text mode, it is highly recommended to specify the encoding type.

# %% [markdown]
# # Closing a File

# %% [markdown]
# Closing a file will free up the resources that were tied with the file and is done using the close() method.
#
# Python has a garbage collector to clean up unreferenced objects but, we must not rely on it to close the file.

# %%
f = open('example.txt')
f.close()

# %% [markdown]
# This method is not entirely safe. If an exception occurs when we are performing some operation with the file, the code exits without closing the file.
#
# A safer way is to use a try...finally block.

# %%
try:
   f = open("example.txt")
   # perform file operations
    
finally:
   f.close()

# %% [markdown]
# This way, we are guaranteed that the file is properly closed even if an exception is raised, causing program flow to stop.
#
# The best way to do this is using the with statement. This ensures that the file is closed when the block inside with is exited.
#
# We don't need to explicitly call the close() method. It is done internally.
#
# with open("example.txt",encoding = 'utf-8') as f:
#     #perform file operations

# %%
with open("example.txt",encoding = 'utf-8') as f:
    # perform file operations
    print(f.read())
# Out:
# This is a Text File

# %% [markdown]
# # Writing to a File

# %% [markdown]
# In order to write into a file we need to open it in **write 'w', append 'a' or exclusive creation 'x' mode**.
#
# We need to be careful with the 'w' mode as it will overwrite into the file if it already exists. All previous data are erased.
#
# Writing a string or sequence of bytes (for binary files) is done using **write()** method. This method returns the number of characters written to the file.

# %%
f = open("test.txt", "w")
f.write("This is a First File\n")
f.write("Contains two lines\n")
f.close()

# %% [markdown]
# This program will create a new file named 'test.txt' if it does not exist. If it does exist, it is overwritten.

# %% [markdown]
# # Reading From a File

# %% [markdown]
# There are various methods available for this purpose. We can use the read(size) method to read in size number of data. If size parameter is not specified, it reads and returns up to the end of the file.

# %%
f = open("test.txt", "r")
f.read()
# Out:
# 'This is a First File\nContains two lines\n'

# %%
f = open("test.txt", "r")
f.read(4)
# Out:
# 'This'

# %%
# = open("test.txt","r")
f.read(10)
# Out:
# ' is a Firs'

# %% [markdown]
# We can change our current file cursor (position) using the seek() method.
#
# Similarly, the **tell()** method returns our current position (in number of bytes).

# %%
f.tell()
# Out:
# 14

# %%
f.seek(0) #bring the file cursor to initial position
# Out:
# 0

# %%
print(f.read()) #read the entire file
# Out:
# This is a First File
# Contains two lines

# %% [markdown]
# We can read a file line-by-line using a for loop. This is both efficient and fast.

# %%
f.seek(0)
for line in f:
    print(line)
# Out:
# This is a First File
#
# Contains two lines

# %% [markdown]
# Alternately, we can use readline() method to read individual lines of a file. This method reads a file till the newline, including the newline character.

# %%
f = open("test.txt", "r")
f.readline()
# Out:
# 'This is a First File\n'

# %%
f.readline()
# Out:
# 'Contains two lines\n'

# %% [markdown]
# If we don't need newline character then we can use "rstrip()" to remove new line character '\n'

# %%
f = open('test.txt', "r")
f.readline().rstrip()
# Out:
# 'This is a First File'

# %%
f.readline().rstrip()
# Out:
# 'Contains two lines'

# %%
#.close()

# %% [markdown]
# The **readlines()** method returns a list of remaining lines of the entire file. All these reading method return empty values when end of file (EOF) is reached.

# %%
f = open('test.txt', 'r')
f.readlines()
# Out:
# ['This is a First File\n', 'Contains two lines\n']

# %%
#All these reading method return empty values when end of file (EOF) is reached.

f.readlines()
# Out:
# []

# %%
f.close() # we can't proceed with the rename and delete operation without closing the file

# %% [markdown]
# # Renaming And Deleting Files In Python.

# %% [markdown]
# While you were using the **read/write** functions, you may also need to **rename/delete** a file in Python. So, there comes a **os** module in Python which brings the support of file **rename/delete** operations.
#
# So, to continue, first of all, you should import the **os** module in your Python script.

# %%
import os

#Rename a file from test.txt to sample.txt
os.rename("test.txt", "sample.txt")

# %%
f = open("sample.txt", "r")
f.readline()
# Out:
# 'This is a First File\n'

# %%
f.close()

# %%
#Delete a file sample.txt
os.remove("sample.txt")

# %%
#f.seek(0)
f= open('sample.txt', 'r')     #we will get FileNotFound error as we are trying to open the file which we had already removed
f.readlines()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-161-67350cab7e21> in <module>
#       1 #f.seek(0)
# ----> 2 f= open('sample.txt', 'r')     #we will get FileNotFound error as we are trying to open the file which we had already removed
#       3 f.readlines()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sample.txt'

# %% [markdown]
# # Python Directory and File Management

# %% [markdown]
# If there are a large number of files to handle in your Python program, you can arrange your code within different directories to make things more manageable.
#
# A directory or folder is a collection of files and sub directories. Python has the os module, which provides us with many useful methods to work with directories (and files as well).

# %% [markdown]
# **Get current Directory**

# %% [markdown]
# We can get the present working directory using the getcwd() method.
#
# This method returns the current working directory in the form of a string.

# %%
import os
os.getcwd()
# Out:
# 'D:\\NAVEEN\\workspace\\python'

# %% [markdown]
# **Changing Directory**

# %% [markdown]
# We can change the current working directory using the chdir() method.
#
# The new path that we want to change to must be supplied as a string to this method. We can use both forward slash (/) or the backward slash (\) to separate path elements.

# %%
os.chdir("D:\\NAVEEN\\AAIC\\Assignments")

# %%
os.getcwd()
# Out:
# 'D:\\NAVEEN\\AAIC\\Assignments'

# %%
os.chdir('D:\\NAVEEN\\workspace\\python')  # changing back to original directory

# %%
os.getcwd()
# Out:
# 'D:\\NAVEEN\\workspace\\python'

# %% [markdown]
# **List Directories and Files**

# %% [markdown]
# All files and sub directories inside a directory can be known using the listdir() method.

# %%
os.listdir(os.getcwd())
# Out:
# ['.ipynb_checkpoints',
#  '1_keywords_identifiers.ipynb',
#  '2_variables_datatypes.ipynb',
#  '3_comments_indentation_statement.ipynb',
#  '4_input_output.ipynb',
#  '5_operators.ipynb',
#  'all_practice examples.ipynb',
#  'break.jpg',
#  'break_continue.ipynb',
#  'break_works.jpg',
#  'continue.jpg',
#  'continue_works.jpg',
#  'Dict.ipynb',
#  'example.py',
#  'example.txt',
#  'File_IO.ipynb',
#  'forLoop.jpg',
#  'for_loop.ipynb',
#  'Functions_Introduction.ipynb',
#  'function_arguments.ipynb',
#  'function_types.ipynb',
#  'function_works.jpg',
#  'if-elif-else.ipynb',
#  'Installation Instructions.txt',
#  'lambda_functions.ipynb',
#  'Lists.ipynb',
#  'modules.ipynb',
#  'package.jpg',
#  'packages.ipynb',
#  'pandas_basics_practice.ipynb',
#  'Python_Control_Flow_if_else.ipynb',
#  'Python_if_elif_else_statement.jpg',
#  'Python_if_else_statement.jpg',
#  'Python_if_statement.jpg',
#  'recursive_functions.ipynb',
#  'Sets.ipynb',
#  'Strings.ipynb',
#  'Tuples.ipynb',
# ...

# %% [markdown]
# **Making New Directory**

# %% [markdown]
# We can make a new directory using the mkdir() method.
#
# This method takes in the path of the new directory. If the full path is not specified, the new directory is created in the current working directory.

# %%
os.mkdir('test')

# %%
os.listdir(os.getcwd())
# Out:
# ['.ipynb_checkpoints',
#  '1_keywords_identifiers.ipynb',
#  '2_variables_datatypes.ipynb',
#  '3_comments_indentation_statement.ipynb',
#  '4_input_output.ipynb',
#  '5_operators.ipynb',
#  'all_practice examples.ipynb',
#  'break.jpg',
#  'break_continue.ipynb',
#  'break_works.jpg',
#  'continue.jpg',
#  'continue_works.jpg',
#  'Dict.ipynb',
#  'example.py',
#  'example.txt',
#  'File_IO.ipynb',
#  'forLoop.jpg',
#  'for_loop.ipynb',
#  'Functions_Introduction.ipynb',
#  'function_arguments.ipynb',
#  'function_types.ipynb',
#  'function_works.jpg',
#  'if-elif-else.ipynb',
#  'Installation Instructions.txt',
#  'lambda_functions.ipynb',
#  'Lists.ipynb',
#  'modules.ipynb',
#  'package.jpg',
#  'packages.ipynb',
#  'pandas_basics_practice.ipynb',
#  'Python_Control_Flow_if_else.ipynb',
#  'Python_if_elif_else_statement.jpg',
#  'Python_if_else_statement.jpg',
#  'Python_if_statement.jpg',
#  'recursive_functions.ipynb',
#  'Sets.ipynb',
#  'Strings.ipynb',
#  'test',
# ...

# %% [markdown]
# However, note that rmdir() method can only remove empty directories.
#
# In order to remove a non-empty directory we can use the rmtree() method inside the shutil module.

# %%
os.rmdir('test') # post removing 'test' directory, It will be not there if we list the directory as above

# %%
os.listdir(os.getcwd())
# Out:
# ['.ipynb_checkpoints',
#  '1_keywords_identifiers.ipynb',
#  '2_variables_datatypes.ipynb',
#  '3_comments_indentation_statement.ipynb',
#  '4_input_output.ipynb',
#  '5_operators.ipynb',
#  'all_practice examples.ipynb',
#  'break.jpg',
#  'break_continue.ipynb',
#  'break_works.jpg',
#  'continue.jpg',
#  'continue_works.jpg',
#  'Dict.ipynb',
#  'example.py',
#  'example.txt',
#  'File_IO.ipynb',
#  'forLoop.jpg',
#  'for_loop.ipynb',
#  'Functions_Introduction.ipynb',
#  'function_arguments.ipynb',
#  'function_types.ipynb',
#  'function_works.jpg',
#  'if-elif-else.ipynb',
#  'Installation Instructions.txt',
#  'lambda_functions.ipynb',
#  'Lists.ipynb',
#  'modules.ipynb',
#  'package.jpg',
#  'packages.ipynb',
#  'pandas_basics_practice.ipynb',
#  'Python_Control_Flow_if_else.ipynb',
#  'Python_if_elif_else_statement.jpg',
#  'Python_if_else_statement.jpg',
#  'Python_if_statement.jpg',
#  'recursive_functions.ipynb',
#  'Sets.ipynb',
#  'Strings.ipynb',
#  'Tuples.ipynb',
# ...

# %%
import shutil           # shull utils module

os.mkdir('test')
os.chdir('./test')              # single dot (./) means current working directory
f = open("testfile.txt",'w')
f.write("Hello World")
os.chdir("../")                 # double dot(../) means the parent directroy in which the current directory is located
os.rmdir('test')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-173-26b2a6a8d00a> in <module>
#       6 f.write("Hello World")
#       7 os.chdir("../")
# ----> 8 os.rmdir('test')
#
# OSError: [WinError 145] The directory is not empty: 'test'

# %%
#As we can see the above OS error, we cannot remove a non-empty directory using rmdir() method

# %%
# we should use 'rmtree()' metod to delete a non-empty directory.

# %%
# remove an non-empty directory
shutil.rmtree('test')              # we will get the permission error as the file is not closed
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-175-cf5327925d17> in <module>
#       1 # remove an non-empty directory
# ----> 2 shutil.rmtree('test')
#
# ~\Anaconda3\lib\shutil.py in rmtree(path, ignore_errors, onerror)
#     498             os.close(fd)
#     499     else:
# --> 500         return _rmtree_unsafe(path, onerror)
#     501
#     502 # Allow introspection of whether or not the hardening against symlink
#
# ~\Anaconda3\lib\shutil.py in _rmtree_unsafe(path, onerror)
#     393                 os.unlink(fullname)
#     394             except OSError:
# --> 395                 onerror(os.unlink, fullname, sys.exc_info())
#     396     try:
#     397         os.rmdir(path)
#
# ~\Anaconda3\lib\shutil.py in _rmtree_unsafe(path, onerror)
#     391         else:
#     392             try:
# --> 393                 os.unlink(fullname)
# ...

# %%
f.close()  # Hence the file is closed, now we can execute the operation.

# %%
# remove an non-empty directory
shutil.rmtree('test')

# %%
os.getcwd()
# Out:
# 'D:\\NAVEEN\\workspace\\python'
